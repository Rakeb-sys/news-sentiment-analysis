# %% [markdown]
# Stock market Analysis for META

# %%
import sys
import os

sys.path.insert(0, os.path.abspath('C:/Users/dagic/OneDrive/Documents/KAIM/Week_1/news-sentiment-analysis'))

print('Path set. Python will now look in:', os.path.abspath('C:/Users/dagic/OneDrive/Documents/KAIM/Week_1/news-sentiment-analysis'))
# Out:
# Path set. Python will now look in: C:\Users\dagic\OneDrive\Documents\KAIM\Week_1\news-sentiment-analysis

# %%
# Import our functions from src/

import pandas as pd
import matplotlib.pyplot as plt
from src.data_cleaner import count_null_values, drop_null_values, save_cleaned_data
from src.data_loader import load_data
from src.stock_market_eda import plot_closing_price, summarize_data

print("All modules imported successfully. Ready to proceed with data loading and analysis.")
# Out:
# All modules imported successfully. Ready to proceed with data loading and analysis.

# %%
# Load the data
data_name = 'META'
load_data?
# Out:
# Signature: load_data(file_path)
# Docstring:
# load data from a csv file,
#
# change 'Date' column to 'date' if it exists,
#
# convert it to datetime format,
#
# set it as index, and sort the data by date
# File:      c:\users\dagic\onedrive\documents\kaim\week_1\news-sentiment-analysis\src\data_loader.py
# Type:      function

# %%
# Load the META stock data
df = load_data(f'../data/raw/yfinance_data/{data_name}.csv')
df.head()
# Out:
# Shape of data: (2923, 5)
#                 Close       High        Low       Open     Volume
# date
# 2012-05-18  37.995762  44.724282  37.767172  41.792356  573576400
# 2012-05-21  33.821495  36.435382  32.797807  36.306177  168192700
# 2012-05-22  30.810066  33.384198  30.750434  32.410203  101786600
# 2012-05-23  31.803938  32.300874  31.167860  31.177799   73600000
# 2012-05-24  32.827625  33.006523  31.575347  32.748117   50237200

# %%
# Check for null values in the data
df = count_null_values(df, data_name)
# Out:
# Null values in META:
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
# get type of df and print first few rows
print(type(df))
print(df.head())
# Out:
# <class 'pandas.DataFrame'>
#                 Close       High        Low       Open     Volume
# date
# 2012-05-18  37.995762  44.724282  37.767172  41.792356  573576400
# 2012-05-21  33.821495  36.435382  32.797807  36.306177  168192700
# 2012-05-22  30.810066  33.384198  30.750434  32.410203  101786600
# 2012-05-23  31.803938  32.300874  31.167860  31.177799   73600000
# 2012-05-24  32.827625  33.006523  31.575347  32.748117   50237200

# %%
# drop null values from the data
df = drop_null_values(df, data_name)
# Out:
# Shape of data after dropping null values for META: (2923, 5)

# %%
df = save_cleaned_data(df, data_name)
# Out:
# Shape of cleaned META: (2923, 5)
# First 5 rows of cleaned META:
#                 Close       High        Low       Open     Volume
# date
# 2012-05-18  37.995762  44.724282  37.767172  41.792356  573576400
# 2012-05-21  33.821495  36.435382  32.797807  36.306177  168192700
# 2012-05-22  30.810066  33.384198  30.750434  32.410203  101786600
# 2012-05-23  31.803938  32.300874  31.167860  31.177799   73600000
# 2012-05-24  32.827625  33.006523  31.575347  32.748117   50237200

# %%
df = pd.read_csv(f'../data/processed/cleaned_{data_name}.csv')
df.head()
# Out:
#          date      Close       High        Low       Open     Volume
# 0  2012-05-18  37.995762  44.724282  37.767172  41.792356  573576400
# 1  2012-05-21  33.821495  36.435382  32.797807  36.306177  168192700
# 2  2012-05-22  30.810066  33.384198  30.750434  32.410203  101786600
# 3  2012-05-23  31.803938  32.300874  31.167860  31.177799   73600000
# 4  2012-05-24  32.827625  33.006523  31.575347  32.748117   50237200

# %%
print(df.dtypes)
# Out:
# date          str
# Close     float64
# High      float64
# Low       float64
# Open      float64
# Volume      int64
# dtype: object

# %%
df = summarize_data(df, data_name)
# Out:
# === META — Key Statistics ===
#   Lowest closing price  : $17.62   on 2012-09-04
#   Highest closing price : $379.84   on 2021-09-07
#   Average closing price : $156.73

# %%
df = plot_closing_price(df, data_name)
