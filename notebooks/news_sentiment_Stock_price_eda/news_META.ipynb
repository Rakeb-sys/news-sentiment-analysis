# %% [markdown]
# ## News Sentiment and META Stock Price EDA

# %%
import sys
import os

sys.path.insert(0, os.path.abspath('C:/Users/dagic/OneDrive/Documents/KAIM/Week_1/news-sentiment-analysis'))

print('Path set. Python will now look in:', os.path.abspath('C:/Users/dagic/OneDrive/Documents/KAIM/Week_1/news-sentiment-analysis'))
# Out:
# Path set. Python will now look in: C:\Users\dagic\OneDrive\Documents\KAIM\Week_1\news-sentiment-analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from nltk.sentiment import SentimentIntensityAnalyzer
from scipy.stats import pearsonr

import nltk as nltk

# %%
# Download VADER lexicon 
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\dagic\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
news_df = pd.read_csv("../../../data/processed/cleaned_raw_analyst_ratings.csv")
# Out:
# C:\Users\dagic\AppData\Local\Temp\ipykernel_10040\886886978.py:1: DtypeWarning: Columns (0: date) have mixed types. Specify dtype option on import or set low_memory=False.
#   news_df = pd.read_csv("../../../data/processed/cleaned_raw_analyst_ratings.csv")

# %%
news_df.head()
# Out:
#                         date  Unnamed: 0  \
# 0  2011-04-27 21:01:48-04:00      357064
# 1  2011-04-28 13:49:29-04:00      437774
# 2  2011-04-28 15:00:36-04:00      350150
# 3  2011-04-29 13:47:06-04:00       49280
# 4  2011-04-29 16:11:05-04:00      539428
#
#                                             headline  \
# 0  ETFs To Watch April 28, 2011 (DGP, IEO, PRN, IDX)
# 1                A New Regional Emerging Markets ETF
# 2  Dejour Extends Credit Facility to October 31st...
# 3        ETF Showdown: Crouching Tigers, Hidden ETFs
# 4  The GDL Fund to Redeem Its Outstanding 8.50% S...
#
#                                                  url        publisher stock
# 0  https://www.benzinga.com/etfs/bond-etfs/11/04/...    ETF Professor   DGP
# 1  https://www.benzinga.com/etfs/emerging-market-...  Sam Subramanian   ESR
# 2  https://www.benzinga.com/news/11/04/1041764/de...       Theo Kratz   DEJ
# 3  https://www.benzinga.com/etfs/emerging-market-...    ETF Professor   AIA
# 4  https://www.benzinga.com/news/11/04/1045464/th...   Benzinga Staff   GDL

# %%
stock_df = pd.read_csv("../../../data/processed/cleaned_META.csv", parse_dates=['date'])

# %%
stock_df.head()
# Out:
#         date      Close       High        Low       Open     Volume
# 0 2012-05-18  37.995762  44.724282  37.767172  41.792356  573576400
# 1 2012-05-21  33.821495  36.435382  32.797807  36.306177  168192700
# 2 2012-05-22  30.810066  33.384198  30.750434  32.410203  101786600
# 3 2012-05-23  31.803938  32.300874  31.167860  31.177799   73600000
# 4 2012-05-24  32.827625  33.006523  31.575347  32.748117   50237200

# %%
print(stock_df.dtypes)
# Out:
# date      datetime64[us]
# Close            float64
# High             float64
# Low              float64
# Open             float64
# Volume             int64
# dtype: object

# %%
# Extract only calendar date
stock_df['date'] = stock_df['date'].dt.date

# %%
print(news_df.dtypes)
# Out:
# date            str
# Unnamed: 0    int64
# headline        str
# url             str
# publisher       str
# stock           str
# dtype: object

# %%
news_df['date'] = pd.to_datetime(news_df['date']).dt.normalize()

# %%
print(news_df.dtypes)
# Out:
# date          datetime64[us, UTC-04:00]
# Unnamed: 0                        int64
# headline                            str
# url                                 str
# publisher                           str
# stock                               str
# dtype: object

# %%
news_df['date'] = pd.to_datetime(news_df['date'])

# %%
# Extract only calendar date
news_df['date'] = news_df['date'].dt.date

# %%
news_df['date'] = pd.to_datetime(news_df['date']).dt.normalize()
stock_df['date'] = pd.to_datetime(stock_df['date']).dt.normalize()

# %%
print('news_df')
print(news_df.dtypes)

print('stock_df')
print(stock_df.dtypes)
# Out:
# news_df
# date          datetime64[s]
# Unnamed: 0            int64
# headline                str
# url                     str
# publisher               str
# stock                   str
# dtype: object
# stock_df
# date      datetime64[s]
# Close           float64
# High            float64
# Low             float64
# Open            float64
# Volume            int64
# dtype: object

# %%
# HANDLE WEEKENDS / HOLIDAYS

# Get valid trading dates
trading_dates = sorted(stock_df['date'].unique())

# Function to map news dates to next trading day
def align_to_trading_day(news_date):

    for trade_date in trading_dates:

        if trade_date >= news_date:
            return trade_date

    return np.nan

# %%
# Align dates in news_df to trading days
news_df['trading_date'] = news_df['date'].apply(align_to_trading_day)

# %% [markdown]
# ## SENTIMENT ANALYSIS USING VADER

# %%
sia = SentimentIntensityAnalyzer()

# Compute sentiment score
news_df['sentiment_score'] = news_df['headline'].apply(
    lambda x: sia.polarity_scores(str(x))['compound']
)

# %% [markdown]
# ## DAILY AVERAGE SENTIMENT

# %%
daily_sentiment = (
    news_df
    .groupby('trading_date')['sentiment_score']
    .mean()
    .reset_index()
)

daily_sentiment.rename(
    columns={'trading_date': 'date'},
    inplace=True
)

# %% [markdown]
# ## DAILY STOCK RETURNS

# %%
stock_df['Daily_Return'] = (
    stock_df['Close'].pct_change() * 100
)

# %% [markdown]
# ## MERGE DATASETS

# %%
merged_df = pd.merge(
    daily_sentiment,
    stock_df[['date', 'Daily_Return']],
    on='date',
    how='inner'
)

# Remove NaN rows
merged_df.dropna(inplace=True)

# %% [markdown]
# ## PEARSON CORRELATION

# %%
corr, p_value = pearsonr(
    merged_df['sentiment_score'],
    merged_df['Daily_Return']
)

print('CORRELATION ANALYSIS')
print('=' * 50)

print(f'Pearson Correlation : {corr:.4f}')
print(f'P-value             : {p_value:.4f}')

print()
# Out:
# CORRELATION ANALYSIS
# ==================================================
# Pearson Correlation : -0.0066
# P-value             : 0.7685

# %% [markdown]
# ## CORRELATION INTERPRETATION

# %%
if corr > 0.5:

    print(
        '-> Strong positive correlation detected.'
    )

    print(
        '   Positive sentiment tends to align with higher stock returns.'
    )

elif corr > 0.2:

    print(
        '-> Weak positive correlation detected.'
    )

    print(
        '   Sentiment may have some influence on stock returns.'
    )

elif corr > -0.2:

    print(
        '-> Very weak or no meaningful correlation detected.'
    )

    print(
        '   News sentiment alone may not strongly explain price movement.'
    )

elif corr > -0.5:

    print(
        '-> Weak negative correlation detected.'
    )

    print(
        '   Negative sentiment may slightly relate to declining returns.'
    )

else:

    print(
        '-> Strong negative correlation detected.'
    )

    print(
        '   Negative sentiment strongly aligns with falling stock prices.'
    )
# Out:
# -> Very weak or no meaningful correlation detected.
#    News sentiment alone may not strongly explain price movement.

# %% [markdown]
# ## Visualization

# %%
plt.figure(figsize=(10, 6))

plt.scatter(
    merged_df['sentiment_score'],
    merged_df['Daily_Return'],
    alpha=0.6
)

plt.title(
    f'Sentiment vs Daily Return\nCorrelation = {corr:.4f}'
)

plt.xlabel('Average Daily Sentiment Score')

plt.ylabel('Daily Stock Return (%)')

plt.grid(True)

plt.show()

# %% [markdown]
# ## SENTIMENT CLASSIFICATION

# %%
def classify_sentiment(score):

    if score > 0.05:
        return 'Positive'

    elif score < -0.05:
        return 'Negative'

    else:
        return 'Neutral'

merged_df['Sentiment_Category'] = (
    merged_df['sentiment_score']
    .apply(classify_sentiment)
)

# %% [markdown]
# ## AVERAGE RETURN BY SENTIMENT CATEGORY

# %%
category_returns = (
    merged_df
    .groupby('Sentiment_Category')['Daily_Return']
    .mean()
)

print()
print('AVERAGE RETURN BY SENTIMENT CATEGORY')
print('=' * 50)

print(category_returns)
# Out:
# AVERAGE RETURN BY SENTIMENT CATEGORY
# ==================================================
# Sentiment_Category
# Negative   -0.087104
# Neutral     0.207478
# Positive    0.110067
# Name: Daily_Return, dtype: float64

# %% [markdown]
# ## Visualization

# %%
plt.figure(figsize=(8, 5))

category_returns.plot(kind='bar')

plt.title('Average Daily Return by Sentiment Category')

plt.ylabel('Average Daily Return (%)')

plt.xlabel('Sentiment Category')

plt.xticks(rotation=0)

plt.grid(True)

plt.show()

# %% [markdown]
# ## Interpretation
#
# The broader relationship is captured in the scatter plot of Sentiment vs Daily Return figure, which shows a Pearson Correlation of -0.0066. While this indicates a very weak positive linear relationship, the p-value of 0.7685 is  not significant metric. Because the p-value is above the conventional 0.05 threshold. It means that any observed relationship is likely due to random chance rather than a meaningful market trend.
#
# As illustrated in the figure of Average Daily Return by Sentiment Category, the fact that "Neutral" sentiment outperforms "Positive" and "Negative" sentiments which suggests that the market may respond more favorably to steady, factual reporting or that positive news is frequently "priced in" before the headlines break.
